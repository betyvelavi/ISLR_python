# %% [markdown]
# # CH 2: Applied Problems
#
# ## Problem 8
# This exercise relates to the `College` data set, which can be found in
# the fle `College.csv` on the book website. It contains a number of
# variables for 777 diferent universities and colleges in the US. The
# variables are:
# ![image.png](attachment:image.png)
#
# ### (a)
# **Use the `pd.read_csv()` function to read the data into `Python`. Call the loaded data `college`. Make sure that you have the directory set to the correct location for the data.**

# %% [markdown]
# First, to set the directory, we need to make sure the code is in the same folder as this Jupyter Notebook or use `os.chdir()` from the `os` library to set the working directory if the data set is in another location within or computer.
#
# In this case, since our dataset is in a separate folder with all other datasets in ISLP package, we will use `os.chdir()`.
#
# Then, we run the code:

# %%
#loading pandas library 
import pandas as pd
#importing to directory library 
import os

# %%
#changing directory to datasets folder 
os.chdir(r"C:\Users\betyv\Documents\0 Self Learning\Statistical Learning wt Applications in Python\Datasets")
#loading the data into python
college = pd.read_csv('College.csv')
college #displays college data frame
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# ### (b)
# **Look at the data used in the notebook by creating and running a new cell with just the code `college` in it. You should notice that the frst column is just the name of each university in a column named something like `Unnamed: 0`. We don’t really want `pandas` to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at the resulting data frames:**
# ![image.png](attachment:image.png)

# %%
college2 = pd.read_csv("College.csv", index_col=0) #sets first column as the index
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3 = college.rename({'Unnamed: 0': 'College'},
                          axis=1)
college3
#kept the default indexing but renamed the 'Unnamamed: 0' column to College
# Out:
#                             College Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college3 = college3.set_index('College')
college3
#renamed the unnamed column to college and set that as the index.
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# **This has used the frst column in the fle as an `index` for the data frame. This means that `pandas` has given each row a name corresponding to the appropriate university. Now you should see that the frst data column is `Private`. Note that the names of the colleges appear on the left of the table. We also introduced a new python object above: a *dictionary*, which is specifed by dictionary `(key, value)` pairs. Keep your modifed version of the data with the following:**
# ```
# college = college3
# ```

# %%
college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# ### (c)
# **Use the `describe()` method of to produce a numerical summary
# of the variables in the data set.**

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### (d)
# **Use the `pd.plotting.scatter_matrix()` function to produce a
# scatterplot matrix of the frst columns `[Top10perc, Apps, Enroll]`.
# Recall that you can reference a list `C` of columns of a data frame
# `A` using `A[C].`**

# %%
pd.plotting.scatter_matrix(college[['Top10perc',
                                    'Apps',
                                    'Enroll']]);
#using guidance from lab,
# double brackets are to select multiple columns and mantain df structure
# ; at the end is to avoid matplot lib output

# %% [markdown]
# ### (e)
# **Use the `boxplot()` method of `college` to produce side-by-side
# boxplots of `Outstate` versus `Private`.**

# %%
college.boxplot('Outstate', by='Private');

# %% [markdown]
# ### (f)
# **Create a new qualitative variable, called `Elite`, by *binning* the
# `Top10perc` variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.**
# ![image.png](attachment:image.png)
# **Use the `value_counts()` method of `college['Elite']` to see how
# many elite universities there are. Finally, use the `boxplot()` method
# again to produce side-by-side boxplots of `Outstate` versus `Elite`.**

# %%
college['Elite'] = pd.cut(college['Top10perc'],
                          [0,0.5,1],
                          labels=['No', 'Yes'])

# %%
college['Elite'].value_counts()
# Out:
# Yes    3
# No     0
# Name: Elite, dtype: int64

# %%
college.boxplot('Outstate', by='Elite');

# %% [markdown]
# ### (g)
# Use the `plot.hist()` method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables. The command `plt.subplots(2, 2)` may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
#import matplotlib.pyplot as plt #to run plt
college.hist('Grad.Rate');
